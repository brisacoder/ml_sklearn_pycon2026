# %% [markdown]
# If you can run the following code blocks without any errors, you should be good to go.

# %%
# these are essential
import pandas
import sklearn
print('good to go!')
# Out:
# good to go!

# %%
# these are non-essential but will be used
import warnings
import numpy
import pickle
import operator
print('even better')
# Out:
# even better
